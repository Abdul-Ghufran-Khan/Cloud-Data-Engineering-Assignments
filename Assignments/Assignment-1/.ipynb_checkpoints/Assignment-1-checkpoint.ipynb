# %% [markdown]
# ## Part 1 PYTHON BASICS (Variables)

# %%
print("Name: Abdul Ghufran\nFather's Name: Sharif Khan\nDate of Birth: August 24, 2004")
# Out:
# Name: Abdul Ghufran
# Father's Name: Sharif Khan
# Date of Birth: August 24, 2004

# %%
name = "Abdul Ghufran"
age = 20
city = "Karachi"
occupation = "Web Developer"

bio = f"Hello, my name is {name}. I'm a {age}-year-old {occupation} living in {city}. I enjoy coding and learning about new technologies."
print(bio)
# Out:
# Hello, my name is Abdul Ghufran. I'm a 20-year-old Web Developer living in Karachi. I enjoy coding and learning about new technologies.

# %%
# Arithmetic Operators
x = 15
y = 4
print(f"x + y = {x + y}")  # Addition
print(f"x - y = {x - y}")  # Subtraction
print(f"x * y = {x * y}")  # Multiplication
print(f"x / y = {x / y}")  # Division
print(f"x % y = {x % y}")  # Modulus
print(f"x ** y = {x ** y}") # Exponentiation
print(f"x // y = {x // y}") # Floor Division

# Comparison Operators
a = 10
b = 20
print(f"a == b is {a == b}") # Equal
print(f"a != b is {a != b}") # Not equal
print(f"a > b is {a > b}")   # Greater than
print(f"a < b is {a < b}")   # Less than
print(f"a >= b is {a >= b}") # Greater than or equal to
print(f"a <= b is {a <= b}") # Less than or equal to

# Assignment Operators
c = 5
c += 3  # c = c + 3
print(f"c += 3 results in {c}")
c *= 2  # c = c * 2
print(f"c *= 2 results in {c}")

# Logical Operators
is_sunny = True
is_warm = False
print(f"is_sunny and is_warm is {is_sunny and is_warm}") # AND
print(f"is_sunny or is_warm is {is_sunny or is_warm}")   # OR
print(f"not is_sunny is {not is_sunny}")                 # NOT

# Identity Operators
list1 = [1, 2, 3]
list2 = [1, 2, 3]
list3 = list1
print(f"list1 is list3 is {list1 is list3}")  # True, they refer to the same object
print(f"list1 is list2 is {list1 is list2}")  # False, they are different objects

# Membership Operators
my_list = [10, 20, 30, 40]
print(f"10 in my_list is {10 in my_list}")      # True
print(f"50 not in my_list is {50 not in my_list}") # True
# Out:
# x + y = 19
# x - y = 11
# x * y = 60
# x / y = 3.75
# x % y = 3
# x ** y = 50625
# x // y = 3
# a == b is False
# a != b is True
# a > b is False
# a < b is True
# a >= b is False
# a <= b is True
# c += 3 results in 8
# c *= 2 results in 16
# is_sunny and is_warm is False
# is_sunny or is_warm is True
# not is_sunny is False
# list1 is list3 is True
# list1 is list2 is False
# 10 in my_list is True
# 50 not in my_list is True

# %%
english_marks = 85
islamiat_marks = 90
math_marks = 78

total_marks = 300

obtained_marks = english_marks + islamiat_marks + math_marks
percentage = (obtained_marks / total_marks) * 100

print(f"English Marks: {english_marks}")
print(f"Islamiat Marks: {islamiat_marks}")
print(f"Math Marks: {math_marks}")
print(f"Total Marks: {total_marks}")
print(f"Obtained Marks: {obtained_marks}")
print(f"Percentage: {percentage:.2f}%")
# Out:
# English Marks: 85
# Islamiat Marks: 90
# Math Marks: 78
# Total Marks: 300
# Obtained Marks: 253
# Percentage: 84.33%

# %% [markdown]
# ## Part 2 PYTHON BASICS (Conditional Statements)

# %%
salary = float(input("Enter your salary: "))
years_of_service = int(input("Enter your years of service: "))

if years_of_service > 5:
    bonus = 0.05 * salary
    print(f"Net bonus amount: Rs. {bonus:.2f}")
else:
    print("You are not eligible for a bonus.")
# Out:
# Enter your salary:  400000
# Enter your years of service:  7
# Net bonus amount: Rs. 20000.00

# %%
age = int(input("Enter your age: "))

if age > 17:
    print("You are eligible for voting.")
else:
    print("You are not eligible for voting.")
# Out:
# Enter your age:  20
# You are eligible for voting.

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number:  88
# The number is even.

# %%
number = int(input("Enter a number: "))

if number % 7 == 0:
    print("The number is divisible by 7.")
else:
    print("The number is not divisible by 7.")
# Out:
# Enter a number:  49
# The number is divisible by 7.

# %%
number = int(input("Enter a number: "))

if number % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Enter a number:  25
# Hello

# %%
number = int(input("Enter a number: "))
last_digit = number % 10
print(f"The last digit of the number is: {last_digit}")
# Out:
# Enter a number:  2344566
# The last digit of the number is: 6

# %%
length = float(input("Enter the length: "))
breadth = float(input("Enter the breadth: "))

if length == breadth:
    print("It is a square.")
else:
    print("It is a rectangle.")
# Out:
# Enter the length:  20
# Enter the breadth:  20.1
# It is a rectangle.

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

if num1 > num2:
    print(f"The greatest number is: {num1}")
elif num2 > num1:
    print(f"The greatest number is: {num2}")
else:
    print("The numbers are equal.")
# Out:
# Enter the first number:  400
# Enter the second number:  401
# The greatest number is: 401

# %%
quantity = int(input("Enter the quantity: "))
cost_per_unit = 100
total_cost = quantity * cost_per_unit

if total_cost > 1000:
    discount = 0.10 * total_cost
    final_cost = total_cost - discount
    print(f"Total cost with discount: Rs. {final_cost:.2f}")
else:
    print(f"Total cost without discount: Rs. {total_cost:.2f}")
# Out:
# Enter the quantity:  11
# Total cost with discount: Rs. 990.00

# %%
marks = int(input("Enter the marks: "))

if marks < 25:
    grade = 'F'
elif 25 <= marks <= 45:
    grade = 'E'
elif 45 < marks <= 50:
    grade = 'D'
elif 50 < marks <= 60:
    grade = 'C'
elif 60 < marks <= 80:
    grade = 'B'
else:
    grade = 'A'
    
print(f"The corresponding grade is: {grade}")
# Out:
# Enter the marks:  88
# The corresponding grade is: A

# %%
classes_held = int(input("Enter the number of classes held: "))
classes_attended = int(input("Enter the number of classes attended: "))

attendance_percentage = (classes_attended / classes_held) * 100

print(f"Percentage of classes attended: {attendance_percentage:.2f}%")

if attendance_percentage >= 75:
    print("The student is allowed to sit in the exam.")
else:
    print("The student is not allowed to sit in the exam.")
# Out:
# Enter the number of classes held:  10
# Enter the number of classes attended:  9
# Percentage of classes attended: 90.00%
# The student is allowed to sit in the exam.

# %%
classes_held = int(input("Enter the number of classes held: "))
classes_attended = int(input("Enter the number of classes attended: "))
medical_cause = input("Do you have a medical cause? (Y/N): ").upper()

attendance_percentage = (classes_attended / classes_held) * 100

print(f"Percentage of classes attended: {attendance_percentage:.2f}%")

if attendance_percentage >= 75 or medical_cause == 'Y':
    print("The student is allowed to sit in the exam.")
else:
    print("The student is not allowed to sit in the exam.")
# Out:
# Enter the number of classes held:  25
# Enter the number of classes attended:  20
# Do you have a medical cause? (Y/N):  y
# Percentage of classes attended: 80.00%
# The student is allowed to sit in the exam.

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# Enter a year:  2004
# 2004 is a leap year.

# %%
age = int(input("Enter age: "))
gender = input("Enter gender (M or F): ").upper()
marital_status = input("Enter marital status (Y or N): ").upper()

if gender == 'F':
    print("You will work in urban areas only.")
elif gender == 'M' and 20 <= age <= 40:
    print("You may work anywhere.")
elif gender == 'M' and 40 < age <= 60:
    print("You will work in urban areas only.")
else:
    print("ERROR: Invalid input for age or gender.")
# Out:
# Enter age:  21
# Enter gender (M or F):  m
# Enter marital status (Y or N):  n
# You may work anywhere.

# %%
units = int(input("Enter the number of units consumed: "))
bill = 0

if units <= 100:
    bill = 0
elif units <= 300:
    bill = (units - 100) * 5
else:
    bill = (200 * 5) + (units - 300) * 10

print(f"Total electricity bill amount is: Rs. {bill}")
# Out:
# Enter the number of units consumed:  200
# Total electricity bill amount is: Rs. 500

# %%
age1 = int(input("Enter age of first person: "))
age2 = int(input("Enter age of second person: "))
age3 = int(input("Enter age of third person: "))

ages = [age1, age2, age3]
oldest = max(ages)
youngest = min(ages)

print(f"The oldest person is {oldest} years old.")
print(f"The youngest person is {youngest} years old.")
# Out:
# Enter age of first person:  20
# Enter age of second person:  25
# Enter age of third person:  18
# The oldest person is 25 years old.
# The youngest person is 18 years old.
