# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/netflix-shows")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/shivamb/netflix-shows?dataset_version_number=5...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1.34M/1.34M [00:01<00:00, 1.10MB/s]
# Extracting files...
# Path to dataset files: C:\Users\LENOVO\.cache\kagglehub\datasets\shivamb\netflix-shows\versions\5

# %%
import pandas as pd

df = pd.read_csv(
    "netflix_titles.csv",
    dtype=str,
    keep_default_na=False
)

# Ensure index is default and not a column
df.reset_index(drop=True, inplace=True)

# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=DESKTOP-G6ELT03;"
    "DATABASE=Quotes;"
    "Trusted_Connection=yes;"
)

cursor = conn.cursor()
cursor.fast_executemany = True




insert_sql = """
INSERT INTO netflix_titles (
    show_id, type, title, director, cast, country,
    date_added, release_year, rating, duration,
    listed_in, description
)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
"""

data = df.values.tolist()

cursor.executemany(insert_sql, data)
conn.commit()
